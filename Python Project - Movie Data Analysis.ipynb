# %% [markdown]
# # Movie Data Analysis

# %%
import pandas as pd
import ast
import json

# %%
data = pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')

df = pd.DataFrame(data)
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
for row in range(len(df['genres'])):
    a = json.loads(df['genres'][row])
    b = [entry['name'] for entry in a]
    df.at[row,'genres'] = b

# %%
df
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4798     220000                      [Action, Crime, Thriller]
# 4799       9000                              [Comedy, Romance]
# 4800          0             [Comedy, Drama, Romance, TV Movie]
# 4801          0                                             []
# 4802          0                                  [Documentary]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
for row in range(len(df['production_companies'])):
    c = json.loads(df['production_companies'][row])
    d = [entry['name'] for entry in c]
    df.at[row,'production_companies'] = d

# %%
df
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4798     220000                      [Action, Crime, Thriller]
# 4799       9000                              [Comedy, Romance]
# 4800          0             [Comedy, Drama, Romance, TV Movie]
# 4801          0                                             []
# 4802          0                                  [Documentary]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# ...

# %% [markdown]
# ## TASK 1 Display the number of rows and columns in the dataset.
# ## Display the titles and genres of the first 50 movies from the dataset

# %%
first_50 = df.head(50)

# %%
titles_genres = first_50[['original_title', 'genres']]
titles_genres
# Out:
#                                  original_title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# ## TASK 2 Identify null values and perform null value treatment

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
df['homepage'] = df['homepage'].fillna('http://www.google.com')

# %%
df['tagline'] = df['tagline'].fillna('Its Popcorn time')

# %%
average = df['runtime'].mean()

df['runtime'] = df['runtime'].fillna(average)

# %%
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                3
# popularity              0
# production_companies    0
# production_countries    0
# release_date            1
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# ## TASK 3 Display the movie categories that have a budget greater than $220,000

# %%
budget_threshold = 220000
filtered_genres = df.loc[df['budget'] > budget_threshold, 'genres']

print("Movie genres with a budget greater than $220,000:")
print(filtered_genres)
# Out:
# Movie genres with a budget greater than $220,000:
# 0       [Action, Adventure, Fantasy, Science Fiction]
# 1                        [Adventure, Fantasy, Action]
# 2                          [Action, Adventure, Crime]
# 3                    [Action, Crime, Drama, Thriller]
# 4                [Action, Adventure, Science Fiction]
#                             ...
# 4680                        [Crime, Horror, Thriller]
# 4682                                         [Horror]
# 4720                                          [Drama]
# 4758                      [Thriller, Science Fiction]
# 4770                                  [Drama, Comedy]
# Name: genres, Length: 3684, dtype: object

# %% [markdown]
# ## TASK 4 Movie categories where revenue is greater than $961,000,000

# %%
revenue_threshold = 961000000
filtered = df.loc[df['revenue'] > revenue_threshold, 'genres']

print("Movie genres with a revenue greater than $961,000,000:")
filtered
# Out:
# Movie genres with a revenue greater than $961,000,000:
# 0       [Action, Adventure, Fantasy, Science Fiction]
# 3                    [Action, Crime, Drama, Thriller]
# 7                [Action, Adventure, Science Fiction]
# 12                       [Adventure, Fantasy, Action]
# 16               [Science Fiction, Action, Adventure]
# 17                       [Adventure, Action, Fantasy]
# 25                         [Drama, Romance, Thriller]
# 26               [Adventure, Action, Science Fiction]
# 28     [Action, Adventure, Science Fiction, Thriller]
# 29                      [Action, Adventure, Thriller]
# 31               [Action, Adventure, Science Fiction]
# 32                       [Family, Fantasy, Adventure]
# 36               [Science Fiction, Action, Adventure]
# 42                        [Animation, Family, Comedy]
# 44                                           [Action]
# 52               [Action, Science Fiction, Adventure]
# ...

# %% [markdown]
# ## TASK 5 Remove the rows with 0 values from both budeget and revenue columns

# %%
df = df.loc[(df['budget'] != 0) & (df['revenue'] != 0)]


df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 3224      27000                                       [Comedy]
# 3225      12000                        [Horror, Comedy, Crime]
# 3226      20000             [Crime, Horror, Mystery, Thriller]
# 3227       7000             [Science Fiction, Drama, Thriller]
# 3228     220000                      [Action, Crime, Thriller]
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# ...

# %% [markdown]
# ## TASK 6 List top 10 movies with highest revenue and top 10 movies with least budget

# %%
# List the top 10 movies with the highest revenue
top_10_highest_revenue = df.nlargest(10, 'revenue')



print("Top 10 movies with the highest revenue:")
top_10_highest_revenue
# Out:
# Top 10 movies with the highest revenue:
#         budget                                          genres  \
# 0    237000000   [Action, Adventure, Fantasy, Science Fiction]
# 25   200000000                      [Drama, Romance, Thriller]
# 16   220000000            [Science Fiction, Action, Adventure]
# 28   150000000  [Action, Adventure, Science Fiction, Thriller]
# 44   190000000                                        [Action]
# 7    280000000            [Action, Adventure, Science Fiction]
# 123  150000000                  [Animation, Adventure, Family]
# 31   200000000            [Action, Adventure, Science Fiction]
# 525   74000000          [Family, Animation, Adventure, Comedy]
# 26   250000000            [Adventure, Action, Science Fiction]
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 25                         http://www.titanicmovie.com     597
# ...

# %%
# List the top 10 movies with the least budget
top_10_least_budget = df.nsmallest(10, 'budget')

print("\nTop 10 movies with the least budget:")
top_10_least_budget
# Out:
# Top 10 movies with the least budget:
#       budget                                             genres  \
# 3078       1                                    [Drama, Comedy]
# 2791       4                              [Drama, Romance, War]
# 2652       7  [Thriller, Action, Horror, Science Fiction, Cr...
# 2671       7                  [Comedy, Drama, Foreign, Romance]
# 3187       8                        [Fantasy, Horror, Thriller]
# 2521      10                           [Drama, Romance, Comedy]
# 2522      10                                 [Horror, Thriller]
# 2405      11                                    [Drama, Action]
# 1694      25                                            [Drama]
# 1579      28                  [Thriller, Action, Comedy, Crime]
#
#                         homepage      id  \
# 3078       http://www.google.com    3082
# 2791       http://www.google.com   22649
# 2652       http://www.google.com   13006
# 2671       http://www.google.com   38415
# ...

# %% [markdown]
# ## TASK 7 How is popularity correlated to budget

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.scatterplot(x='popularity', y='budget', data=df, marker='o', color='blue')
plt.title("Correlation between Popularity and Budget")
plt.xlabel("popularity")
plt.ylabel("budget")
plt.show()

# %% [markdown]
# ### Popularity is not so correlated with budget of the movie

# %% [markdown]
# ## TASK 8 Display names of all production companies along with number of times they appear in the dataset

# %%
production_company_counts = df['production_companies'].value_counts()

print("Production Company Counts:")
print(production_company_counts)
# Out:
# Production Company Counts:
# [Paramount Pictures]                                                                       48
# []                                                                                         41
# [Universal Pictures]                                                                       35
# [New Line Cinema]                                                                          29
# [Columbia Pictures]                                                                        28
#                                                                                            ..
# [Universal Pictures, Bristol Bay Productions, Baldwin Entertainment Group, Anvil Films]     1
# [Columbia Pictures, Original Film, Kanzaman, Relativity Media, Art In Motion]               1
# [The Montecito Picture Company, De Line Pictures, Bernard Gayle Productions]                1
# [Camelot Productions, Canal Plus Group, Ixtlan Productions, Warner Bros.]                   1
# ...

# %% [markdown]
# ## TASK 9 Display names of top 25 production companies based on the number of movies they have produced in descending order of the number of movies produced

# %%
top_25_production_companies = df['production_companies'].value_counts().head(25)

print("Top 25 Production Companies based on the number of movies produced:")
top_25_production_companies
# Out:
# Top 25 Production Companies based on the number of movies produced:
# [Paramount Pictures]                                     48
# []                                                       41
# [Universal Pictures]                                     35
# [New Line Cinema]                                        29
# [Columbia Pictures]                                      28
# [Twentieth Century Fox Film Corporation]                 25
# [Warner Bros.]                                           24
# [Metro-Goldwyn-Mayer (MGM)]                              24
# [Walt Disney Pictures]                                   18
# [Touchstone Pictures]                                    15
# [Columbia Pictures Corporation]                          13
# [Dimension Films]                                        13
# [DreamWorks Animation]                                   12
# [Walt Disney Pictures, Pixar Animation Studios]          11
# [United Artists]                                         10
# ...

# %% [markdown]
# ## TASK 10
#
# ## Sort the data in descending order based on revenue and filter the top 500 movies. Find the measures of central tendency for the following columns using the filtered data: budget, revenue, runtime. Perform outlier analysis for the above three columns using box plot

# %%
# Sort data in descending order based on revenue
sorted_df = df.sort_values(by='revenue', ascending=False)

# Filter the top 500 movies
filtered_df = sorted_df.head(500)

# Calculate measures of central tendency for budget, revenue, and runtime columns
budget_mean = filtered_df['budget'].mean()
budget_median = filtered_df['budget'].median()
budget_mode = filtered_df['budget'].mode().iloc[0]

revenue_mean = filtered_df['revenue'].mean()
revenue_median = filtered_df['revenue'].median()
revenue_mode = filtered_df['revenue'].mode().iloc[0]

runtime_mean = filtered_df['runtime'].mean()
runtime_median = filtered_df['runtime'].median()
runtime_mode = filtered_df['runtime'].mode().iloc[0]

# Display the measures of central tendency
print("Measures of Central Tendency for Budget:")
print("Mean:", budget_mean)
print("Median:", budget_median)
print("Mode:", budget_mode)

print("\nMeasures of Central Tendency for Revenue:")
print("Mean:", revenue_mean)
print("Median:", revenue_median)
print("Mode:", revenue_mode)

print("\nMeasures of Central Tendency for Runtime:")
print("Mean:", runtime_mean)
print("Median:", runtime_median)
print("Mode:", runtime_mode)
# Out:
# Measures of Central Tendency for Budget:
# Mean: 103193736.0
# Median: 95000000.0
# Mode: 150000000
#
# Measures of Central Tendency for Revenue:
# Mean: 458577595.062
# Median: 363001569.5
# Mode: 217764291
#
# Measures of Central Tendency for Runtime:
# Mean: 118.72
# Median: 116.0
# Mode: 115.0

# %%
# Perform outlier analysis using box plots
plt.figure(figsize=(10, 6))

# Box plot for budget
plt.subplot(1, 3, 1)
plt.boxplot(filtered_df['budget'], vert=False)
plt.title("Outlier Analysis - budget")

# Box plot for revenue
plt.subplot(1, 3, 2)
plt.boxplot(filtered_df['revenue'], vert=False)
plt.title("Outlier Analysis - revenue")

# Box plot for runtime
plt.subplot(1, 3, 3)
plt.boxplot(filtered_df['runtime'], vert=False)
plt.title("Outlier Analysis - runtime")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## TASK 11 Display the names of movies along with their runtime for those movies that have above average runtime, using the data of previous task

# %%
# Calculate the average runtime for the filtered movies
average_runtime = filtered_df['runtime'].mean()

# Filter movies with above-average runtime
above_average_runtime_movies = filtered_df[filtered_df['runtime'] > average_runtime]

# Display the names of movies along with their runtime for movies with above-average runtime
print("Movies with Above-Average Runtime:")
above_average_runtime_movies[['original_title', 'runtime']]
# Out:
# Movies with Above-Average Runtime:
#         original_title  runtime
# 0               Avatar    162.0
# 25             Titanic    194.0
# 16        The Avengers    143.0
# 28      Jurassic World    124.0
# 44           Furious 7    137.0
# ...                ...      ...
# 502       The Terminal    128.0
# 390   It's Complicated    121.0
# 1556        Knocked Up    129.0
# 687       Jack Reacher    130.0
# 684         Collateral    120.0
#
# [234 rows x 2 columns]
