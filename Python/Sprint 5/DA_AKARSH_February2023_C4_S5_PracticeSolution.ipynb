# %% [markdown]
# ## Employee Data Analysis

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
data = pd.read_excel('DS1_C4_S5_Employee_Data_Practice.xlsx')
df = pd.DataFrame(data)
df
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 1             1011  Female        IT               48000   27                4
# 2             1012    Male      Sales              75000   31                7
# 3             1013    Male      Sales              61000   29                6
# 4             1014  Female    Finance              45000   27                4
# ..             ...     ...        ...                ...  ...              ...
# 65            1074  Female         HR              82500   43               13
# 66            1075    Male      Sales              53500   28                5
# 67            1076  Female         HR              57000   29                6
# 68            1077    Male      Sales              66500   33                7
# 69            1078    Male    Finance              92000   45               19
#
# [70 rows x 6 columns]

# %%
# Task 1

xy = df.groupby('Department').sum()[['Annual Salary ($)']]
xy
# Out:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
# Ploting the graph


xy.plot.bar(title = 'Department-wise Annual Salary', ylabel = 'Salary', color = 'g', width = 0.4);

# %%
# Task 2

dept = df.groupby(by = ['Department', 'Gender'])['Gender'].count()
dept
# Out:
# Department  Gender
# Finance     Female     2
#             Male      11
# HR          Female    11
#             Male       4
# IT          Female    10
#             Male      12
# Sales       Female     4
#             Male      16
# Name: Gender, dtype: int64

# %%
# Creating dataframe
dataframe = pd.DataFrame({'Department': ['Fincance', 'HR', 'IT', 'Sales'], 'Male Count': [11,4,12,16], 'Female Count': [2,11,10,4]})
dataframe
# Out:
#   Department  Male Count  Female Count
# 0   Fincance          11             2
# 1         HR           4            11
# 2         IT          12            10
# 3      Sales          16             4

# %%
dataframe.plot(x= 'Department',
              kind = 'bar',
              stacked = False,
              title = 'Gender-wise count of departments', xlabel = 'Department', ylabel = ' Employee count');

# %%
# Task 3

IT = df[(df['Department'] == 'IT ') & (df['Work_Experience'] == 0)]
print("The Average salary of a Fresher in IT department is:", IT['Annual Salary ($)'].mean())
IT
# Out:
# The Average salary of a Fresher in IT department is: 28100.0
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 7             1017    Male        IT               28000   23                0
# 12            1022    Male        IT               29000   22                0
# 46            1055    Male        IT               27500   22                0
# 47            1056  Female        IT               29000   23                0

# %%
# Task 4

sal = df.groupby('Department').sum()[['Annual Salary ($)']]
sal
# Out:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
dep = ['Finance', 'HR', 'IT', 'Sales']
salary = [790000, 987000, 1282900, 1089000]

plt.pie(salary, labels = dep, autopct = '%.2f %%' )
plt.title('Dept-wise sum of Annual salaries')
plt.show()

# %%
# Task 5

plt.title('Distribution of Employee count by Age group')
plt.xlabel('Age group')
plt.ylabel('Employee Count')
plt.hist(df['Age'], bins = 5,edgecolor = 'r');

# %%
# Task 6

trend = df[['Annual Salary ($)', 'Work_Experience']]
trend = trend.sort_values(by = 'Work_Experience')
trend
# Out:
#     Annual Salary ($)  Work_Experience
# 0               27000                0
# 47              29000                0
# 46              27500                0
# 38              28000                0
# 7               28000                0
# ..                ...              ...
# 57              88000               16
# 58              90000               17
# 69              92000               19
# 29             140000               20
# 64             170000               24
#
# [70 rows x 2 columns]

# %%
# Scatter Plot
plt.xlabel('Work Experience')
plt.ylabel('Annual Salary')
plt.title('Salary Trend based on Employee experience')
plt.scatter(trend['Work_Experience'], trend['Annual Salary ($)']);

# %%
# Task 7

df.boxplot(column = ['Annual Salary ($)'], by = 'Department')
plt.tight_layout()

# %%
# The departments HR and IT has outliers in Annual Salary.
