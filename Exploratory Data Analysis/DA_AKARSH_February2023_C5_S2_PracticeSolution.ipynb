# %% [markdown]
# # Employee Attrition Analysis

# %%
import matplotlib.pyplot as plt          
from tabulate import tabulate             
import matplotlib as mat                   
import seaborn as sns                    
import pandas as pd                        
import numpy as np                     
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('DS1_C5_S2_EmployeeAttrition_Data_Practice.csv')

df = pd.DataFrame(data)
df
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     41.0       Yes      Travel_Rarely                   Sales
# 1     49.0        No  Travel_Frequently  Research & Development
# 2     37.0       Yes      Travel_Rarely  Research & Development
# 3     33.0        No  Travel_Frequently  Research & Development
# 4     27.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 0                    1  Life Sciences               1
# 1                    8  Life Sciences               2
# ...

# %% [markdown]
# # Task 1

# %% [markdown]
# # Bi-variate Analysis

# %%
def seprate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:               
        if df[column].nunique() < 10:       
                                                    
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(df)        


from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  -----------------------
# Attrition                 Age
# BusinessTravel            DistanceFromHome
# Department                EmployeeNumber
# EducationField            HourlyRate
# EnvironmentSatisfaction   MonthlyIncome
# Gender                    NumCompaniesWorked
# JobInvolvement            TotalWorkingYears
# JobRole                   YearsAtCompany
# JobSatisfaction           YearsInCurrentRole
# MaritalStatus             YearsSinceLastPromotion
# Over18                    YearsWithCurrManager
# OverTime
# PerformanceRating
# RelationshipSatisfaction
# TrainingTimesLastYear
# WorkLifeBalance

# %% [markdown]
# ## 1. Analysis of Business travel with Employee Attrition

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "BusinessTravel", hue = "Attrition", data = df)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')
plt.show()

# %% [markdown]
# ##### Maximum number of employees who are still working in the company travel rarely.

# %% [markdown]
# ## 2. Analysis of Education field with employee attrition

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "EducationField", hue = "Attrition", data = df)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')
plt.show()

# %% [markdown]
# ##### Maximum number of employees who are still working in the company are from Life Sciences and Medical education field respectively. Employees who have left the company are also maximum in Life Sciences education field.

# %% [markdown]
# ## 3. Analysis of department with employee attrition

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Department", hue = "Attrition", data = df)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')
plt.show()

# %% [markdown]
# ##### Maximum number of employees who are still working in the company are from Research & Development department. Employees leaving the company are also more from the same department.

# %% [markdown]
# ## 4. Analysis of Environment satisfaction with employee attrition

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "EnvironmentSatisfaction", hue = "Attrition", data = df)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')
plt.show()

# %% [markdown]
# ##### Maximum number of employees who are still working in the company have environment satisfaction score of 3 and 4 respectively. Employees who have left the company have a score of 1.

# %% [markdown]
# ## 5. Analysis of Gender with employee attrition

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Attrition", data = df)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')
plt.show()

# %% [markdown]
# ##### Maximum number of employees who are still working in the company are Males. They have the higher number of leaving the company as well.

# %% [markdown]
# ## 6. Analysis of Marital Status with employee attrition

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "MaritalStatus", hue = "Attrition", data = df)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')
plt.show()

# %% [markdown]
# ##### Maximum number of Single marital status employees tend to leave the company while Married employees have not left the company in more number.

# %% [markdown]
# ## 7. Analysis of Over Time with employee attrition

# %%
percentage = (df["OverTime"].value_counts()/len(df))*100      # value count is a function to calulate the number of the column marital status 
                                                                        #keeping its classes as index. 
print(percentage)

labels = list(df["OverTime"].value_counts().index)            # value_counts returns the count of the classes present in the marital status and its index which is the class name 
                                                                         # is accessed by the index; in sequence format and then converted into the list. 
plt.pie(percentage,labels = labels, autopct= "%0.2f%%", textprops ={'fontsize': 13})           # autpct: is the way how the number would print on the graph.
plt.title('Over time category-wise employee count')
plt.legend()
plt.show()
# Out:
# No     71.70068
# Yes    28.29932
# Name: OverTime, dtype: float64

# %% [markdown]
# ##### Maximun number of employees who are working in the company prefer not to work overtime.

# %% [markdown]
# ## 8. Analysis of Performance rating with employee attrition

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "PerformanceRating", hue = "Attrition", data = df)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')
plt.show()

# %% [markdown]
# ##### Employees who have left the company have a performance rating of '3'.

# %% [markdown]
# ## 9. Analysis of Job Satisfaction with employee attrition

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "JobSatisfaction", hue = "Attrition", data = df)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')
plt.show()

# %% [markdown]
# ##### Employees who have left the company have job satisfaction score of '3'. Employees who are still with the company have a score of '4'.

# %% [markdown]
# # Task 2

# %% [markdown]
# ## CAT - NUM Analysis

# %% [markdown]
# ## 1. Analysis of Age with Employee Attrition

# %%
fig, ax = plt.subplots(1, 2, figsize= (17, 7))   
sns.histplot(x = df["Age"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["Age"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ##### Employees who have left the company fall under 28 to 38 age group

# %% [markdown]
# ## 2. Analysis of Hourly Rate with Employee Attrition

# %%
fig, ax = plt.subplots(1, 2, figsize= (17, 7))   
sns.histplot(x = df["HourlyRate"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["HourlyRate"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ##### Hourly Rate is evenly spread across the data. It is a normal distribution.

# %% [markdown]
# ## 3. Analysis of Monthly Income with Employee Attrition

# %%
fig, ax = plt.subplots(1, 2, figsize= (17, 7))   
sns.histplot(x = df["MonthlyIncome"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["MonthlyIncome"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ##### Employee attrition 'Yes' has a right skewed data with some of the employees having higher monthly income.

# %% [markdown]
# ## 4. Analysis of Distance from Home with Employee Attrition

# %%
fig, ax = plt.subplots(1, 2, figsize= (17, 7))   
sns.histplot(x = df["DistanceFromHome"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["DistanceFromHome"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ##### Attrition 'Yes' employees is evenly spread across the Distance from Home data.

# %% [markdown]
# ## 5. Analysis of Total working Years with Employee Attrition

# %%
fig, ax = plt.subplots(1, 2, figsize= (17, 7))   
sns.histplot(x = df["TotalWorkingYears"], hue = df["Attrition"], ax = ax[0])
sns.boxplot(y = df["TotalWorkingYears"], x = df["Attrition"], ax = ax[1])
plt.show()

# %% [markdown]
# ##### Tenure of employees who have left the company is less which indicates that they do not stay with the company for longer period of time

# %% [markdown]
# # Task 3

# %% [markdown]
# ## Job Role-wise count of Attrited employees who travel rarely

# %%
attrited = df[(df['Attrition'] == 'Yes') & (df['BusinessTravel'] == 'Travel_Rarely')]
attrited
# Out:
#        Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0     41.0       Yes  Travel_Rarely                   Sales                 1
# 2     37.0       Yes  Travel_Rarely  Research & Development                 2
# 14    28.0       Yes  Travel_Rarely  Research & Development                24
# 21    36.0       Yes  Travel_Rarely                   Sales                 9
# 24    34.0       Yes  Travel_Rarely  Research & Development                 6
# ...    ...       ...            ...                     ...               ...
# 1390  28.0       Yes  Travel_Rarely  Research & Development                17
# 1396  53.0       Yes  Travel_Rarely                   Sales                24
# 1442  29.0       Yes  Travel_Rarely  Research & Development                 1
# 1444  56.0       Yes  Travel_Rarely  Research & Development                 7
# 1461  50.0       Yes  Travel_Rarely                   Sales                28
#
# ...

# %%
sns.countplot(y=attrited["BusinessTravel"], hue=attrited["JobRole"], data=attrited)
plt.legend(bbox_to_anchor=(1.05,1));

# %% [markdown]
# ##### Attrited employees who travel rarely are more from Laboratory Technician Job Role

# %% [markdown]
# # Task 4 -Job-wise Employee Attrition

# %%
jobwise = df[(df['EducationField'] == 'Life Sciences') | (df['EducationField'] == 'Medical')]
jobwise
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     41.0       Yes      Travel_Rarely                   Sales
# 1     49.0        No  Travel_Frequently  Research & Development
# 3     33.0        No  Travel_Frequently  Research & Development
# 4     27.0        No      Travel_Rarely  Research & Development
# 5     32.0        No  Travel_Frequently  Research & Development
# ...    ...       ...                ...                     ...
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 0                    1  Life Sciences               1
# 1                    8  Life Sciences               2
# ...

# %%
sns.countplot(y=jobwise["JobRole"], hue=jobwise["Attrition"])
plt.legend(bbox_to_anchor=(1,1.05));

# %% [markdown]
# ##### More number of employees have attired from Research Scientist Job Role

# %% [markdown]
# # Task 5 - Gender-wise Employee Attrition from Sales department

# %%
genderwise = df[df['Department'] == 'Sales']
genderwise
# Out:
#        Age Attrition     BusinessTravel Department  DistanceFromHome  \
# 0     41.0       Yes      Travel_Rarely      Sales                 1
# 18    53.0        No      Travel_Rarely      Sales                 2
# 21    36.0       Yes      Travel_Rarely      Sales                 9
# 27    42.0        No      Travel_Rarely      Sales                 8
# 29    46.0        No      Travel_Rarely      Sales                 2
# ...    ...       ...                ...        ...               ...
# 1454  45.0        No      Travel_Rarely      Sales                20
# 1461  50.0       Yes      Travel_Rarely      Sales                28
# 1462  39.0        No      Travel_Rarely      Sales                24
# 1464  26.0        No      Travel_Rarely      Sales                 5
# 1468  49.0        No  Travel_Frequently      Sales                 2
#
#      EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# ...

# %%
sns.countplot(x=genderwise["Attrition"], hue=genderwise["Gender"])
plt.legend(bbox_to_anchor=(1,1.02));

# %% [markdown]
# ##### It's the Male employees who have attrited more than Female employees.
